# %%
import pystac_client
import planetary_computer
import pprint
import json
import rasterio
import rioxarray
from IPython.display import Image
import pystac

catalog = pystac_client.Client.open(
    "https://planetarycomputer.microsoft.com/api/stac/v1",
    modifier=planetary_computer.sign_inplace,
)

# %%
area_of_interest = {
    "type": "Point",
    "coordinates": [44.6509, -63.5923],
}

time_range = "2024-09-26/2024-10-06"

search = catalog.search(
    collections=["landsat-c2-l2"], intersects=area_of_interest, datetime=time_range
)
data = search.item_collection_as_dict()

# %%
# pprint.pprint(search.item_collection_as_dict())
json_object = json.dumps(data, indent = 4) 
print(json_object)
# Out:
# {
#     "type": "FeatureCollection",
#     "features": [
#         {
#             "id": "LC08_L2SR_150105_20240928_02_T2",
#             "bbox": [
#                 39.65598587119305,
#                 -65.88805080841654,
#                 47.25466407755062,
#                 -62.57461919158346
#             ],
#             "type": "Feature",
#             "links": [
#                 {
#                     "rel": "collection",
#                     "type": "application/json",
#                     "href": "https://planetarycomputer.microsoft.com/api/stac/v1/collections/landsat-c2-l2"
#                 },
#                 {
#                     "rel": "parent",
#                     "type": "application/json",
#                     "href": "https://planetarycomputer.microsoft.com/api/stac/v1/collections/landsat-c2-l2"
#                 },
#                 {
#                     "rel": "root",
#                     "type": "application/json",
# ...

# %%
items = search.item_collection()
items.item.url = 0

# %%
# Define the area of interest and time range
area_of_interest = {
    "type": "Point",
    "coordinates": [44.6509, -63.5923],
}

time_range = "2024-10-01/2024-10-06"

# Search the catalog
search = catalog.search(
    collections=["landsat-c2-l2"], intersects=area_of_interest, datetime=time_range
)

# Get the first item from the search results
item = next(search.items())

# Sign the item to get access to the data
signed_item = planetary_computer.sign(item)

pprint.pprint(signed_item.assets)
# Get the asset URL for the desired band, e.g., B4 (Red band)

Image(url=signed_item.assets["rendered_preview"].href, width=500)
# asset_href = signed_item.assets["red"].href

# ds = rioxarray.open_rasterio(asset_href)
# # Open the asset with rasterio
# with rasterio.open(asset_href) as src:
#     # Get the pixel value at the specified coordinates
#     row, col = src.index(44.6509, -63.5923)
#     pixel_value = src.read(1)[row, col]

# print(f"Pixel value at {area_of_interest['coordinates']}: {pixel_value}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 14
#       9 # Search the catalog
#      10 search = catalog.search(
#      11     collections=["landsat-c2-l2"], intersects=area_of_interest, datetime=time_range
#      12 )
# ---> 14 print(len(search.items()))
#      15 # Get the first item from the search results
#      16 item = next(search.items())
#
# TypeError: object of type 'generator' has no len()

# %%
import pystac
import planetary_computer
import rioxarray

item_url = "https://planetarycomputer.microsoft.com/api/stac/v1/collections/landsat-c2-l2/items/LC09_L2SP_121034_20240925_02_T1"

# Load the individual item metadata and sign the assets
item = pystac.Item.from_file(item_url)

signed_item = planetary_computer.sign(item)

# Open one of the data assets (other asset keys to use: 'red', 'blue', 'drad', 'emis', 'emsd', 'trad', 'urad', 'atran', 'cdist', 'green', 'nir08', 'lwir11', 'swir16', 'swir22', 'coastal', 'qa_pixel', 'qa_radsat', 'qa_aerosol')
asset_href = signed_item.assets["qa"].href
ds = rioxarray.open_rasterio(asset_href)
ds
# Out:
# <xarray.DataArray (band: 1, y: 7741, x: 7611)> Size: 118MB
# [58916751 values with dtype=int16]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 61kB 5.565e+05 5.565e+05 ... 7.848e+05 7.848e+05
#   * y            (y) float64 62kB 4.265e+06 4.265e+06 ... 4.033e+06 4.033e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     AREA_OR_POINT:  Point
#     _FillValue:     -9999
#     scale_factor:   1.0
#     add_offset:     0.0
